# %% [markdown]
# # **GRUPO 07 - ALGAS**
# **Caetano Domingues, Davi Hilário, Daniel Andrade, Danielle Yumi
# Munakata, Eduardo Corrêa e Gustavo Pereira Castro**

# %% [markdown]
# ### Importando Bibliotecas

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mysql-connector-python in /home/danielle/.local/lib/python3.8/site-packages (8.1.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in /home/danielle/.local/lib/python3.8/site-packages (from mysql-connector-python) (4.21.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
import sys
import math
import psutil as ps
import matplotlib.pyplot as plt
import numpy as np
import mysql.connector
from datetime import datetime
import random
import matplotlib.dates as mdates
import datetime
from datetime import timedelta
import json

# %% [markdown]
# ### Criando conexão com o banco de dados

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="urubu100",
  password="urubu100",
  database="algas"
)

mycursor = mydb.cursor()
sql = "INSERT INTO dados (valor) VALUES (%s)"

# %% [markdown]
# ### Definindo Funções

# %% [markdown]
# Função get_transactions()

# %%
def get_transactions(start, stop, step):
    transactions = []
    for i in range(start, stop, step):
        transactions.append(i)
    return transactions

# %% [markdown]
# Função get_time()

# %%
def get_time():
    agora = time.time()
    hoje_meia_noite = datetime.combine(datetime.today(), datetime.min.time())
    meia_noite_timestamp = time.mktime(hoje_meia_noite.timetuple())
    diferenca_segundos = agora - meia_noite_timestamp
    diferenca_minutos = diferenca_segundos / 60

    return diferenca_minutos

# %% [markdown]
# Função run()

# %%
def run(start, stop, step):
    transactions = get_transactions(start, stop, step)
    arr = []
    arrTime = {
        'inicio': [],
        'inFirstFor': [],
        'inSecondFor': [],
        'afterAppend': []
    }
    usages = {
        'cpu': [],
        'memory': []
    }
    inicio = get_time()
    arrTime['inicio'].append(inicio)
    for transaction in transactions:
        arrTime['inFirstFor'].append(get_time())
        val = (math.floor(get_time() * 100) / 100,)
        mycursor.execute(sql, val)
        mydb.commit()
        for i in range(1, transaction):
            inSecondFor = get_time()
            arrTime['inSecondFor'].append(inSecondFor)
            arr.append(str(i)*(i%1000))
            afterAppend = get_time()
            arrTime['afterAppend'].append(afterAppend)
            usages['cpu'].append(ps.cpu_percent())
            usages['memory'].append(ps.virtual_memory().percent)
            val = (math.floor(get_time() * 100) / 100,)
            mycursor.execute(sql, val)

        print(f'Transação {transaction} encerrada!')

    return {
        'dados': arr,
        'times': arrTime,
        'usages': usages
    }

# %% [markdown]
# Função plot()

# %%
def plot(data):
  xpoints = np.array(list(range(0, len(data))))
  ypoints = np.array(data)

  plt.plot(xpoints, ypoints)
  plt.show()

# %% [markdown]
# Algoritmo de Temperatura

# %%
import random
import mysql.connector
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
from datetime import timedelta
import json

mydb = mysql.connector.connect(
    host="localhost",
    user="urubu100",
    password="urubu100",
    database="algas"
)

# %%
mycursor = mydb.cursor(dictionary=True)

temperatures = [random.uniform(0, 40) for _ in range(100)]
now = datetime.datetime.now()
date_list = [now + timedelta(seconds=i) for i in range(100)]

sql_insert = "INSERT INTO dados (valor) VALUES (%s)"
for temp in temperatures:
    mycursor.execute(sql_insert, (temp,))
    mydb.commit()

sql_select = "SELECT * FROM dados ORDER BY id DESC LIMIT 100"
mycursor.execute(sql_select)
resultados = mycursor.fetchall()
resultados.reverse()

tipo_dado_nome = "Temperatura"
sensor_nome = " IR MLX90614"

output = []
for row in resultados:
    output.append({
        "id": row["id"],
        "valor_leitura": float(row["valor"]),
        "tipo_dado": {
            "nome": tipo_dado_nome
        },
        "sensor": {
            "nome": sensor_nome
        }
    })

print(json.dumps(output, indent=2, ensure_ascii=False))

x_axis = mdates.date2num(date_list)

plt.figure(figsize=(15, 8))
plt.plot(x_axis, temperatures, marker='o', linestyle='-', color='b', markersize=5, label=tipo_dado_nome)

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.gca().xaxis.set_major_locator(mdates.SecondLocator(interval=10))

plt.xlabel("Hora")
plt.ylabel("Temperatura (°C)")
plt.title("Dados de Temperatura")
plt.legend()
plt.grid(True)
plt.gcf().autofmt_xdate()
plt.show()

mycursor.close()
mydb.close()
# Out:
# [
#   {
#     "id": 202,
#     "valor_leitura": 18.31,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 203,
#     "valor_leitura": 0.29,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 204,
#     "valor_leitura": 18.03,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 205,
#     "valor_leitura": 7.79,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 206,
#     "valor_leitura": 3.79,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 207,
#     "valor_leitura": 36.52,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 208,
#     "valor_leitura": 37.12,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 209,
#     "valor_leitura": 38.07,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 210,
#     "valor_leitura": 25.48,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 211,
#     "valor_leitura": 11.98,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 212,
#     "valor_leitura": 32.58,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 213,
#     "valor_leitura": 33.14,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 214,
#     "valor_leitura": 30.56,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 215,
#     "valor_leitura": 37.76,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 216,
#     "valor_leitura": 30.79,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 217,
#     "valor_leitura": 11.08,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 218,
#     "valor_leitura": 1.67,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 219,
#     "valor_leitura": 14.41,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 220,
#     "valor_leitura": 6.49,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 221,
#     "valor_leitura": 39.04,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 222,
#     "valor_leitura": 34.84,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 223,
#     "valor_leitura": 16.95,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 224,
#     "valor_leitura": 20.75,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 225,
#     "valor_leitura": 35.69,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 226,
#     "valor_leitura": 13.23,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 227,
#     "valor_leitura": 9.1,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 228,
#     "valor_leitura": 37.83,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 229,
#     "valor_leitura": 21.98,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 230,
#     "valor_leitura": 32.11,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 231,
#     "valor_leitura": 12.18,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 232,
#     "valor_leitura": 27.73,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 233,
#     "valor_leitura": 32.4,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 234,
#     "valor_leitura": 3.86,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 235,
#     "valor_leitura": 28.88,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 236,
#     "valor_leitura": 26.21,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 237,
#     "valor_leitura": 28.38,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 238,
#     "valor_leitura": 19.94,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 239,
#     "valor_leitura": 10.56,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 240,
#     "valor_leitura": 8.02,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 241,
#     "valor_leitura": 18.63,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 242,
#     "valor_leitura": 29.07,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 243,
#     "valor_leitura": 15.27,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 244,
#     "valor_leitura": 35.62,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 245,
#     "valor_leitura": 37.2,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 246,
#     "valor_leitura": 21.41,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 247,
#     "valor_leitura": 37.37,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 248,
#     "valor_leitura": 9.49,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 249,
#     "valor_leitura": 15.52,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 250,
#     "valor_leitura": 31.91,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 251,
#     "valor_leitura": 12.91,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 252,
#     "valor_leitura": 30.48,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 253,
#     "valor_leitura": 8.9,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 254,
#     "valor_leitura": 6.25,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 255,
#     "valor_leitura": 33.11,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 256,
#     "valor_leitura": 19.57,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 257,
#     "valor_leitura": 0.99,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 258,
#     "valor_leitura": 27.75,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 259,
#     "valor_leitura": 6.0,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 260,
#     "valor_leitura": 10.92,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 261,
#     "valor_leitura": 27.71,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 262,
#     "valor_leitura": 5.15,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 263,
#     "valor_leitura": 0.55,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 264,
#     "valor_leitura": 18.15,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 265,
#     "valor_leitura": 19.01,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 266,
#     "valor_leitura": 17.62,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 267,
#     "valor_leitura": 14.96,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 268,
#     "valor_leitura": 38.41,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 269,
#     "valor_leitura": 1.84,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 270,
#     "valor_leitura": 37.48,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 271,
#     "valor_leitura": 20.94,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 272,
#     "valor_leitura": 14.19,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 273,
#     "valor_leitura": 31.21,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 274,
#     "valor_leitura": 9.59,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 275,
#     "valor_leitura": 10.42,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 276,
#     "valor_leitura": 19.05,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 277,
#     "valor_leitura": 17.98,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 278,
#     "valor_leitura": 38.85,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 279,
#     "valor_leitura": 3.09,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 280,
#     "valor_leitura": 34.5,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 281,
#     "valor_leitura": 5.06,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 282,
#     "valor_leitura": 34.77,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 283,
#     "valor_leitura": 22.6,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 284,
#     "valor_leitura": 11.09,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 285,
#     "valor_leitura": 25.09,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 286,
#     "valor_leitura": 2.27,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 287,
#     "valor_leitura": 9.23,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 288,
#     "valor_leitura": 3.04,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 289,
#     "valor_leitura": 12.85,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 290,
#     "valor_leitura": 10.59,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 291,
#     "valor_leitura": 34.91,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 292,
#     "valor_leitura": 18.28,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 293,
#     "valor_leitura": 35.43,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 294,
#     "valor_leitura": 29.01,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 295,
#     "valor_leitura": 30.86,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 296,
#     "valor_leitura": 3.52,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 297,
#     "valor_leitura": 3.41,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 298,
#     "valor_leitura": 23.18,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 299,
#     "valor_leitura": 5.8,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 300,
#     "valor_leitura": 18.61,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   },
#   {
#     "id": 301,
#     "valor_leitura": 9.69,
#     "tipo_dado": {
#       "nome": "Temperatura"
#     },
#     "sensor": {
#       "nome": " IR MLX90614"
#     }
#   }
# ]

# %% [markdown]
# Algoritmo Fator Potência

# %%
import random
import mysql.connector
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
from datetime import timedelta
import json

mydb = mysql.connector.connect(
    host="localhost",
    user="urubu100",
    password="urubu100",
    database="algas"
)
mycursor = mydb.cursor(dictionary=True)

def gerar_dados_pzem():
    tensao = round(random.uniform(80, 260), 1)
    corrente = round(random.uniform(0, 100), 2)
    potencia_aparente = round(tensao * corrente, 1)
    fator_potencia = round(random.uniform(0.5, 1.0), 2)
    return fator_potencia

fatores_potencia = [gerar_dados_pzem() for _ in range(30)]
now = datetime.datetime.now()
date_list = [now + timedelta(seconds=i) for i in range(30)]

sql_insert = "INSERT INTO dados (valor) VALUES (%s)"
for fator in fatores_potencia:
    mycursor.execute(sql_insert, (fator,))
    mydb.commit()

sql_select = "SELECT * FROM dados ORDER BY id DESC LIMIT 30"
mycursor.execute(sql_select)
resultados = mycursor.fetchall()
resultados.reverse()

tipo_dado_nome = "Fator de Potência"
sensor_nome = "PZEM-004T"

output = []
for row in resultados:
    output.append({
        "id": row["id"],
        "valor_leitura": float(row["valor"]),
        "tipo_dado": {
            "nome": tipo_dado_nome
        },
        "sensor": {
            "nome": sensor_nome
        }
    })

print(json.dumps(output, indent=2, ensure_ascii=False))

x_axis = mdates.date2num(date_list)

plt.figure(figsize=(15, 8))
plt.plot(x_axis, fatores_potencia, marker='o', linestyle='-', color='g', markersize=5, label=tipo_dado_nome)

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.gca().xaxis.set_major_locator(mdates.SecondLocator(interval=2))

plt.xlabel("Hora")
plt.ylabel("Fator de Potência")
plt.title("Dados de Fator de Potência")
plt.legend()
plt.grid(True)
plt.gcf().autofmt_xdate()
plt.show()

mycursor.close()
mydb.close()
# Out:
# [
#   {
#     "id": 302,
#     "valor_leitura": 0.7,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 303,
#     "valor_leitura": 0.95,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 304,
#     "valor_leitura": 0.52,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 305,
#     "valor_leitura": 0.97,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 306,
#     "valor_leitura": 0.88,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 307,
#     "valor_leitura": 0.76,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 308,
#     "valor_leitura": 0.73,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 309,
#     "valor_leitura": 0.84,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 310,
#     "valor_leitura": 0.54,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 311,
#     "valor_leitura": 0.99,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 312,
#     "valor_leitura": 0.8,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 313,
#     "valor_leitura": 0.63,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 314,
#     "valor_leitura": 0.77,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 315,
#     "valor_leitura": 0.56,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 316,
#     "valor_leitura": 0.97,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 317,
#     "valor_leitura": 0.78,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 318,
#     "valor_leitura": 0.91,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 319,
#     "valor_leitura": 0.78,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 320,
#     "valor_leitura": 0.9,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 321,
#     "valor_leitura": 0.53,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 322,
#     "valor_leitura": 0.69,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 323,
#     "valor_leitura": 0.56,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 324,
#     "valor_leitura": 0.79,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 325,
#     "valor_leitura": 0.9,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 326,
#     "valor_leitura": 0.52,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 327,
#     "valor_leitura": 0.71,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 328,
#     "valor_leitura": 0.57,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 329,
#     "valor_leitura": 0.83,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 330,
#     "valor_leitura": 0.73,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   },
#   {
#     "id": 331,
#     "valor_leitura": 0.66,
#     "tipo_dado": {
#       "nome": "Fator de Potência"
#     },
#     "sensor": {
#       "nome": "PZEM-004T"
#     }
#   }
# ]

# %% [markdown]
# Algoritmo Ámpere

# %%
import time
import os
import random
import json
import mysql.connector

os.environ['TZ'] = 'America/Sao_Paulo'
time.tzset()

mydb = mysql.connector.connect(
    host="localhost",
    user="urubu100",
    password="urubu100",
    database="algas"
)
mycursor = mydb.cursor()

def calculate_current(primary_voltage):
    primary_enroll = 1
    secundary_enroll = 160
    power = 25

    primary_current = power / primary_voltage
    secundary_current = primary_current * (secundary_enroll / primary_enroll)

    if secundary_current < 5:
        secundary_current = 5

    format_time = time.strftime('%H:%M:%S')

    return {
        "valor_leitura": {
            "corrente_primaria": round(primary_current, 4),
            "corrente_secundaria": round(secundary_current, 4),
            "tempo": format_time
        },
        "tipo_dado": {
            "nome": "Ampere"
        },
        "sensor": {
            "nome": "RCI-32"
        }
    }

sample = 30

records = []

for _ in range(sample):
    primary_voltage = random.randint(1000, 36000)
    record = calculate_current(primary_voltage)
    records.append(record)

    sql_insert = "INSERT INTO dados (valor) VALUES (%s)"
    mycursor.execute(sql_insert, (record["valor_leitura"]["corrente_primaria"],))
    mydb.commit()

mycursor.close()
mydb.close()

print(json.dumps(records, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0058,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0049,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0011,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0023,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0014,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0016,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.001,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0007,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0015,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0008,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0035,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0011,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0008,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0015,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0036,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0053,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0013,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0013,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0013,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0031,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0013,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0009,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0011,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0026,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0012,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0018,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.001,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0053,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0008,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   },
#   {
#     "valor_leitura": {
#       "corrente_primaria": 0.0021,
#       "corrente_secundaria": 5,
#       "tempo": "19:11:14"
#     },
#     "tipo_dado": {
#       "nome": "Ampere"
#     },
#     "sensor": {
#       "nome": "RCI-32"
#     }
#   }
# ]

# %% [markdown]
# Algoritmo Harmonica

# %%
from random import uniform, randint

# %%
def get_harmonics(noise = 1):

    # Noise/ruído: indica a faixa de valores que poderão ser retornados. Em situações normais, o valor da harmônica deve estar entre 0% e 5%, onde, quando maior for essa porcentagem,
    # pior é a qualidade da energia.

    # Valores disponíveis para noise:
    # 1 - Low
    # 2 - Medium
    # 3 - High
    # 3 - Very High

    if (noise == 1):
        minimum = 0.00
        maximum = 5.00
    elif (noise == 2):
        minimum = 0.00
        maximum = 25.00
    elif (noise == 3):
        minimum = 0.00
        maximum = 75.00
    elif (noise == 4):
        minimum = 0.00
        maximum = 100.00
    else:
        print(f"No such value ({noise}) for noise is allowed. Using default values.")
        minimum = 0.00
        maximum = 5.00

    accuracy = 1.0

    # se o valor do random for 0, irá somar 1 no valor final da harmônica. Se for 1, irá diminuir 1 no valor final da harmônica.
    is_accuracy_positive_or_negative = randint(0, 1)

    harmonics = accuracy + (uniform(minimum, maximum)) if is_accuracy_positive_or_negative == 0 else (uniform(minimum, maximum)) - accuracy

    if(harmonics < 0):
        harmonics = 0.01
    if(harmonics > 100):
        harmonics = 100.00

    return {
        "valor_leitura": round(harmonics,2),
        "tipo_dado": {
            "nome": "Harmônicas",
            "descricao": "Valor da harmônica obtido pelo sensor."
        },
        "sensor": {
            "nome": "AcuRev 2100 Multi-Circuit",
            "fabricante": "AccuEnergy",
            "datasheet": "https://www.accuenergy.com/wp-content/uploads/AcuRev-2100-Multi-Circuit-Submeter-Datasheet.pdf"
        }
    }

# %%
noise = 4

print(get_harmonics(noise))
print(get_harmonics(noise)["valor_leitura"])
# Out:
# {'valor_leitura': 99.05, 'tipo_dado': {'nome': 'Harmônicas', 'descricao': 'Valor da harmônica obtido pelo sensor.'}, 'sensor': {'nome': 'AcuRev 2100 Multi-Circuit', 'fabricante': 'AccuEnergy', 'datasheet': 'https://www.accuenergy.com/wp-content/uploads/AcuRev-2100-Multi-Circuit-Submeter-Datasheet.pdf'}}
# 26.05

# %% [markdown]
# Algoritmo Tensão

# %%
# !pip install matplotlib
# !pip install tqdm
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Requirement already satisfied: matplotlib in /home/danielle/.local/lib/python3.8/site-packages (3.7.2)
# Requirement already satisfied: cycler>=0.10 in /home/danielle/.local/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/danielle/.local/lib/python3.8/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: numpy>=1.20 in /home/danielle/.local/lib/python3.8/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/danielle/.local/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/danielle/.local/lib/python3.8/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/danielle/.local/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/danielle/.local/lib/python3.8/site-packages (from matplotlib) (6.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/danielle/.local/lib/python3.8/site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: packaging>=20.0 in /home/danielle/.local/lib/python3.8/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/danielle/.local/lib/python3.8/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.14.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/danielle/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib) (3.16.2)
# Requirement already satisfied: tqdm in /home/danielle/.local/lib/python3.8/site-packages (4.50.2)

# %%
BASE = 23000

def capturar_tensao():
    variacao_moment = np.random.normal(0, 150)

    pico = 0
    if np.random.rand() < 0.001:
        pico = np.random.pareto(2) * 1000
    if np.random.pareto(2) < 1:
        pico = -pico

    return BASE + variacao_moment + pico

def execucao(max):
    sizes = range(1, max+1, 1)

    tensions = []
    for n in tqdm(sizes):
        data = 'g' * n

        while data:
            data = data[1:]
            tensions.append(capturar_tensao())
    return tensions

e = execucao(10)
pass
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 18901.78it/s]

# %%
tamanhos = [10, 100, 1000, 10000]
tensoes = []
for i, t in enumerate(tamanhos):
    print(f"Execução {i+1}.")
    tensoes.append(execucao(t))
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 19169.58it/s]
# 100%|██████████| 100/100 [00:00<00:00, 3292.46it/s]
#  22%|██▏       | 216/1000 [00:00<00:00, 2151.62it/s]
# Execução 1.
# Execução 2.
# Execução 3.
# 100%|██████████| 1000/1000 [00:01<00:00, 530.54it/s]
#   3%|▎         | 316/10000 [00:00<00:05, 1628.97it/s]
# Execução 4.
# 100%|██████████| 10000/10000 [03:08<00:00, 52.95it/s]

# %%
for i, t in enumerate(tamanhos):
    plt.title(f"Tensão - {t} resultados")
    plt.xlabel('Quantidade de coletas')
    plt.ylabel('Tensão (em volts)')
    plt.axhline(BASE, color="red", linestyle="--")
    plt.grid(True)
    plt.legend()

    plt.scatter(range(len(tensoes[i])), tensoes[i], label=f'{t} - Tensões')
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# O Kernel deu pane ao executar o código na célula atual ou em uma célula anterior.
#
# Analise o código nas células para identificar uma possível causa da pane.
#
# Clique <a href='https://aka.ms/vscodeJupyterKernelCrash'>aqui</a> para obter mais informações.
#
# Consulte Jupyter <a href='command:jupyter.viewOutput'>log</a> para obter mais detalhes.

# %% [markdown]
# Algoritmo Frêquencia

# %%
import time
import sys
import math
import random
import psutil as ps
import matplotlib.pyplot as plt
import numpy as np
import mysql.connector
from datetime import datetime

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="urubu100",
  password="urubu100",
  database="algas"
)

mycursor = mydb.cursor()
sql = "INSERT INTO dados (valor) VALUES (%s)"

# %%
def get_transactions(start, stop, step):
    transactions = []
    for i in range(start, stop, step):
        transactions.append(i)
    return transactions

# %%
def get_time():
    agora = time.time()
    hoje_meia_noite = datetime.combine(datetime.today(), datetime.min.time())
    meia_noite_timestamp = time.mktime(hoje_meia_noite.timetuple())
    diferenca_segundos = agora - meia_noite_timestamp
    diferenca_minutos = diferenca_segundos / 60

    return diferenca_minutos

# %%
def run(start, stop, step):
    transactions = get_transactions(start, stop, step)
    arr = []
    arrTime = []
    for transaction in transactions:
        val = round(random.uniform(59.9,60.1),2)
        if random.randint(1,50) == 23:
            val = val + random.randint(1,50)
        arr.append(val)
        mycursor.execute(sql, (val,))
        mydb.commit()

        arrTime.append(math.floor(get_time() * 100) / 100,)



    return {
        'dados': arr,
        'times': arrTime,
    }

# %%
def plot(data):
  xpoints = np.array(list(range(0, len(data))))
  ypoints = np.array(data)
  plt.plot(xpoints, ypoints)
  plt.show()

# %%
def plot(data):
  xpoints = np.array(list(range(0, len(data))))
  ypoints = np.array(data)
  plt.plot(xpoints, ypoints)
  plt.show()

# %%
result = run(100, 600, 100)

plot(result['dados'])

# %%
result = run(1_000, 6_000, 1_000)

plot(result['dados'])

# %%
result = run(100_000, 600_000, 100_000)

plot(result['dados'])

# %%
result = run(1_000_000, 6_000_000, 1_0)

plot(result['dados'])
